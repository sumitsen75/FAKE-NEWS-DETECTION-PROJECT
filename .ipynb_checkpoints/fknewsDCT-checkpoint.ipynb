# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
fake = pd.read_csv('C:\\Users\\snipe\\FND Project\\Fake.csv',encoding='latin1') 
true = pd.read_csv('C:\\Users\\snipe\\FND Project\\True.csv',encoding='latin1')

# %%
fake.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['target'] = 'FAKE'
true['target'] = 'REAL'

# %%
data = pd.concat([fake, true]).reset_index(drop = True)
data
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Yearâ...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obamaâs Na...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
from sklearn.utils import shuffle
data = shuffle(data)
data = data.reset_index(drop=True)
data.head()
# Out:
#                                                title  \
# 0  An OBAMA âLOW LEVEL OFFENDERâ Gets Early R...
# 1   People Are Queuing Up To Get This Trump Tatto...
# 2  Trump administration backpedals on citizenship...
# 3  U.N.'s Guterres calls on Myanmar to end violen...
# 4  Knifeman yelling 'Allahu Akbar' shot dead afte...
#
#                                                 text       subject  \
# 0  According to the mother of the 35 year old mur...      politics
# 1  A Florida man recently had a tattoo of Donald ...          News
# 2  WASHINGTON (Reuters) - A U.S. official told Co...  politicsNews
# 3  UNITED NATIONS (Reuters) - U.N. Secretary-Gene...     worldnews
# 4  MARSEILLE, France/PARIS (Reuters) - Two women ...     worldnews
#
#                   date target
# 0          Mar 4, 2016   FAKE
# 1       April 14, 2016   FAKE
# 2     October 3, 2017    REAL
# 3  September 13, 2017    REAL
# 4     October 1, 2017    REAL

# %%
data.drop(["date"],axis=1,inplace=True)
data.drop(["title"],axis=1,inplace=True)
data
# Out:
#                                                     text       subject target
# 0      According to the mother of the 35 year old mur...      politics   FAKE
# 1      A Florida man recently had a tattoo of Donald ...          News   FAKE
# 2      WASHINGTON (Reuters) - A U.S. official told Co...  politicsNews   REAL
# 3      UNITED NATIONS (Reuters) - U.N. Secretary-Gene...     worldnews   REAL
# 4      MARSEILLE, France/PARIS (Reuters) - Two women ...     worldnews   REAL
# ...                                                  ...           ...    ...
# 44893  Donald Trump is absolutely LIVID that the crow...          News   FAKE
# 44894  21st Century Wire says Here s an unusual, but ...   Middle-east   FAKE
# 44895  Donald Trump held a press conference today to ...     left-news   FAKE
# 44896  If you re keeping track, so far, Donald Trump ...          News   FAKE
# 44897  LONDON (Reuters) - London police said an item ...     worldnews   REAL
#
# [44898 rows x 3 columns]

# %%
data.isnull().any()
# Out:
# text       False
# subject    False
# target     False
# dtype: bool

# %%
data['text'] = data['text'].apply(lambda x: x.lower())
data
# Out:
#                                                     text       subject target
# 0      according to the mother of the 35 year old mur...      politics   FAKE
# 1      a florida man recently had a tattoo of donald ...          News   FAKE
# 2      washington (reuters) - a u.s. official told co...  politicsNews   REAL
# 3      united nations (reuters) - u.n. secretary-gene...     worldnews   REAL
# 4      marseille, france/paris (reuters) - two women ...     worldnews   REAL
# ...                                                  ...           ...    ...
# 44893  donald trump is absolutely livid that the crow...          News   FAKE
# 44894  21st century wire says here s an unusual, but ...   Middle-east   FAKE
# 44895  donald trump held a press conference today to ...     left-news   FAKE
# 44896  if you re keeping track, so far, donald trump ...          News   FAKE
# 44897  london (reuters) - london police said an item ...     worldnews   REAL
#
# [44898 rows x 3 columns]

# %%
import string
def punctuation_removal(text):
    all_list = [char for char in text if char not in string.punctuation]
    clean_str = ''.join(all_list)
    return clean_str
data['text'] = data['text'].apply(punctuation_removal)
data
# Out:
#                                                     text       subject target
# 0      according to the mother of the 35 year old mur...      politics   FAKE
# 1      a florida man recently had a tattoo of donald ...          News   FAKE
# 2      washington reuters  a us official told congres...  politicsNews   REAL
# 3      united nations reuters  un secretarygeneral an...     worldnews   REAL
# 4      marseille franceparis reuters  two women were ...     worldnews   REAL
# ...                                                  ...           ...    ...
# 44893  donald trump is absolutely livid that the crow...          News   FAKE
# 44894  21st century wire says here s an unusual but e...   Middle-east   FAKE
# 44895  donald trump held a press conference today to ...     left-news   FAKE
# 44896  if you re keeping track so far donald trump ha...          News   FAKE
# 44897  london reuters  london police said an item tha...     worldnews   REAL
#
# [44898 rows x 3 columns]

# %%
#stopwords removal
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
data['text'] = data['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
data.head(50)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\snipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                  text          subject target
# 0   according mother 35 year old murdered woman ma...         politics   FAKE
# 1   florida man recently tattoo donald trump inked...             News   FAKE
# 2   washington reuters us official told congress t...     politicsNews   REAL
# 3   united nations reuters un secretarygeneral ant...        worldnews   REAL
# 4   marseille franceparis reuters two women stabbe...        worldnews   REAL
# 5   president trump addressed america people today...         politics   FAKE
# 6   united nations reuters france made new plea mo...     politicsNews   REAL
# 7   bill maher began interview yawninducing democr...         politics   FAKE
# 8   one many discussions assassinating trump ontwi...         politics   FAKE
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(data['text'], data.target, test_size=0.2)

# %%
#tfidf_vectorizer
tfidf_vectorizer=TfidfVectorizer(stop_words='english', max_df=0.7)
tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
tfidf_test=tfidf_vectorizer.transform(x_test)

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
pipeline = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                    ('dtmodel', DecisionTreeClassifier())])

# %%
modeldt = pipeline.fit(x_train,y_train)

# %%
prediction = modeldt.predict(x_test)
print("Accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
# Out:
# Accuracy: 99.63%

# %%
pred = modeldt.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#         FAKE       1.00      1.00      1.00      4762
#         REAL       1.00      1.00      1.00      4218
#
#     accuracy                           1.00      8980
#    macro avg       1.00      1.00      1.00      8980
# weighted avg       1.00      1.00      1.00      8980

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[4746   16]
#  [  17 4201]]

# %%
from sklearn import metrics
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greens):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("")
    else:
        print('')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = metrics.confusion_matrix(y_test, pred)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])

# %%
pickle.dump(modeldt, open('model.pkl','wb'))  
modeldt = pickle.load(open('model.pkl','rb'))

# %%
print(modeldt.predict(["How elite leftists celebrate America s Independence Day The Kennedy clan gathered at their Hyannis Port compound on Cape Cod over the weekend for their annual Fourth of July festivities, and took some time to attack Donald Trump.Robert F. Kennedy Jr. s daughter Kathleen, between known as Kick, posted a photos of a pinata of The Donald from a family party over the weekend. It s yuge party!,  wrote Kick in the caption of the Instagram post, which also showed some of her family members milling about in the background.She later deleted the Instagram post just before 11am on Monday.Via: Daily Mail"]))
# Out:
# ['FAKE']

# %%
